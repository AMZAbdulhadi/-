# %% [markdown]
# <a href="https://colab.research.google.com/github/AMZAbdulhadi/-/blob/main/quickstarts/Get_started_managed_agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1

# %% [markdown]
# ## Import required libraries and load the dataset into a pandas DataFrame.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('/content/digitamart_orders.csv')

# %% [markdown]
# ## Display the first few rows to inspect data structure and column names.

# %%
# Preview initial rows
df.head()
# Out:
#    order_id  order_date   city  product_category  product_name  order_total  \
# 0      1001  2024-11-23  Cairo       Electronics   USB-C Cable       425.15
# 1      1002  2024-08-04  Cairo  Food & Groceries  Olive Oil 1L       232.62
# 2      1003  2025-01-30   Giza  Food & Groceries     Spice Set       131.09
# 3      1004  2024-06-10   Giza          Clothing  Leather Belt      1609.73
# 4      1005  2024-01-25  Aswan       Electronics    Power Bank      4483.71
#
#    delivery_minutes  customer_rating payment_method  customer_age
# 0              26.0              5.0         Wallet          18.0
# 1             137.0              4.0         Wallet          63.0
# 2              38.0              2.0    Credit Card          21.0
# 3              55.0              3.0  Bank Transfer          26.0
# 4              22.0              5.0         Wallet         150.0

# %% [markdown]
# ## Check dataset information including data types and non-null counts.

# %%
# Inspect summary info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326 entries, 0 to 325
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          326 non-null    int64
#  1   order_date        320 non-null    object
#  2   city              324 non-null    object
#  3   product_category  326 non-null    object
#  4   product_name      326 non-null    object
#  5   order_total       324 non-null    float64
#  6   delivery_minutes  324 non-null    float64
#  7   customer_rating   321 non-null    float64
#  8   payment_method    326 non-null    object
#  9   customer_age      324 non-null    float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 25.6+ KB
